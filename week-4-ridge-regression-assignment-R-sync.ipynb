# %% [markdown]
# # Regression Week 4: Ridge Regression (gradient descent)
# ## Sync with R

# %% [markdown]
# In this notebook, you will implement ridge regression via gradient descent. You will:
# * Convert an SFrame into a Numpy array
# * Write a Numpy function to compute the derivative of the regression weights with respect to a single feature
# * Write gradient descent function to compute the regression weights given an initial weight vector, step size, tolerance, and L2 penalty

# %% [markdown]
# # Fire up graphlab create

# %% [markdown]
# Make sure you have the latest version of GraphLab Create (>= 1.7)

# %%
import graphlab
print graphlab.version
graphlab.canvas.set_target('ipynb')
import pprint
# Out:
# 1.8.1

# %%
glb_rsp_var_raw = "price"
glb_rsp_var = glb_rsp_var_raw
glbObsTrnPartitionSeed = 123

feats = ['sqft_living', 'sqft_living15']

# %% [markdown]
# # Load in house sales data
#
# Dataset is from house sales in King County, the region where the city of Seattle, WA is located.

# %%
glbObsTrn = graphlab.SFrame('data/kc_house_train_data.csv')
# Out:
# PROGRESS: Finished parsing file /Users/bbalaji-2012/Documents/Work/Courses/Coursera/uwashington/uwashington-machinelearning/notebooks/data/kc_house_train_data.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.068525 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[int,str,float,int,float,int,int,float,int,int,int,int,int,int,int,int,int,float,float,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /Users/bbalaji-2012/Documents/Work/Courses/Coursera/uwashington/uwashington-machinelearning/notebooks/data/kc_house_train_data.csv
# PROGRESS: Parsing completed. Parsed 17384 lines in 0.077529 secs.

# %%
glbObsNew = graphlab.SFrame('data/kc_house_test_data.csv')
# Out:
# PROGRESS: Finished parsing file /Users/bbalaji-2012/Documents/Work/Courses/Coursera/uwashington/uwashington-machinelearning/notebooks/data/kc_house_test_data.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.02731 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[int,str,float,int,float,int,int,float,int,int,int,int,int,int,int,int,int,float,float,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /Users/bbalaji-2012/Documents/Work/Courses/Coursera/uwashington/uwashington-machinelearning/notebooks/data/kc_house_test_data.csv
# PROGRESS: Parsing completed. Parsed 4229 lines in 0.031905 secs.

# %% [markdown]
# If we want to do any "feature engineering" like creating new features or adjusting existing ones we should do this directly using the SFrames as seen in the first notebook of Week 2. For this notebook, however, we will work with the existing features.

# %% [markdown]
# # Import useful functions from previous notebook

# %% [markdown]
# As in Week 2, we convert the SFrame into a 2D Numpy array. Copy and paste `get_numpy_data()` from the second notebook of Week 2.

# %%
import numpy as np # note this allows us to refer to numpy as np instead 
print np.__version__
# Out:
# 1.10.4

# %%
def get_numpy_data(data_sframe, features, output):
    data_sframe['constant'] = 1 # this is how you add a constant column to an SFrame
    # add the column 'constant' to the front of the features list so that we can extract it along with the others:
    features = ['constant'] + features # this is how you combine two lists
    # select the columns of data_SFrame given by the features list into the SFrame features_sframe (now including constant):
    features_sframe = data_sframe[features]
    
    # the following line will convert the features_SFrame into a numpy matrix:
    feature_matrix = features_sframe.to_numpy()
    # assign the column of data_sframe associated with the output to the SArray output_sarray
    output_sarray = data_sframe[output]
    
    # the following will convert the SArray into a numpy array by first converting it to a list
    output_array = output_sarray.to_numpy()
    return(feature_matrix, output_array)

# %% [markdown]
# Also, copy and paste the `predict_output()` function to compute the predictions for an entire matrix of features given the matrix and the weights:

# %%
def predict_output(feature_matrix, weights):
    # assume feature_matrix is a numpy matrix containing the features as columns and weights is a corresponding numpy array
    # create the predictions vector by using np.dot()
    predictions = np.dot(feature_matrix, weights)

    return(predictions)

(example_features, example_output) = \
    get_numpy_data(glbObsTrn, ['sqft_living'], 'price')
test_predictions = predict_output(example_features, np.array([1., 1.]))
print test_predictions[0] # should be 1181.0
print test_predictions[1] # should be 2571.0

test_predictions = predict_output(example_features, np.array([10., 2.]))
print test_predictions[0] # should be 2370.0
print test_predictions[1] # should be 5150.0
# Out:
# 1181.0
# 2571.0
# 2370.0
# 5150.0

# %% [markdown]
# # Computing the Derivative

# %% [markdown]
# We are now going to move to computing the derivative of the regression cost function. Recall that the cost function is the sum over the data points of the squared difference between an observed output and a predicted output, plus the L2 penalty term.
# ```
# Cost(w)
# = SUM[ (prediction - output)^2 ]
# + l2_penalty*(w[0]^2 + w[1]^2 + ... + w[k]^2).
# ```
#
# Since the derivative of a sum is the sum of the derivatives, we can take the derivative of the first part (the RSS) as we did in the notebook for the unregularized case in Week 2 and add the derivative of the regularization part.  As we saw, the derivative of the RSS with respect to `w[i]` can be written as:
# ```
# 2*SUM[ error*[feature_i] ].
# ```
# The derivative of the regularization term with respect to `w[i]` is:
# ```
# 2*l2_penalty*w[i].
# ```
# Summing both, we get
# ```
# 2*SUM[ error*[feature_i] ] + 2*l2_penalty*w[i].
# ```
# That is, the derivative for the weight for feature i is the sum (over data points) of 2 times the product of the error and the feature itself, plus `2*l2_penalty*w[i]`.
#
# **We will not regularize the constant.**  Thus, in the case of the constant, the derivative is just twice the sum of the errors (without the `2*l2_penalty*w[0]` term).
#
# Recall that twice the sum of the product of two vectors is just twice the dot product of the two vectors. Therefore the derivative for the weight for feature_i is just two times the dot product between the values of feature_i and the current errors, plus `2*l2_penalty*w[i]`.
#
# With this in mind complete the following derivative function which computes the derivative of the weight given the value of the feature (over all data points) and the errors (over all data points).  To decide when to we are dealing with the constant (so we don't regularize it) we added the extra parameter to the call `feature_is_constant` which you should set to `True` when computing the derivative of the constant and `False` otherwise.

# %%
def feature_derivative_ridge(errors, feature, weight, l2_penalty, \
                             feature_is_constant):
    # If feature_is_constant is True, derivative is twice the dot product of errors and feature
    derivative = 2 * np.dot(errors, feature)
    
    # Otherwise, derivative is twice the dot product plus 2*l2_penalty*weight
    if not feature_is_constant:
        derivative += 2 * l2_penalty * weight
    
    return derivative

# %% [markdown]
# To test your feature derivartive run the following:

# %%
(example_features, example_output) = \
    get_numpy_data(glbObsTrn, ['sqft_living'], 'price') 
my_weights = np.array([1., 10.])
test_predictions = predict_output(example_features, my_weights) 
errors = test_predictions - example_output # prediction errors

# next two lines should print the same values
print feature_derivative_ridge(errors, example_features[:,1], my_weights[1], 1, False)
print np.sum(errors*example_features[:,1])*2+20.
print errors[0:5]
print example_features[0:5, 1]
print (errors * example_features[:,1])[0:5]
print ''

# next two lines should print the same values
print feature_derivative_ridge(errors, example_features[:,0], my_weights[0], 1, True)
print np.sum(errors)*2.
# Out:
# -4.55328923355e+13
# -4.55328923355e+13
# [-210099. -512299. -172299. -584399. -493199.]
# [1180 2570  770 1960 1680]
# [ -2.47916820e+08  -1.31660843e+09  -1.32670230e+08  -1.14542204e+09
#   -8.28574320e+08]
#
# -18029479492.0
# -18029479492.0

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# Now we will write a function that performs a gradient descent. The basic premise is simple. Given a starting point we update the current weights by moving in the negative gradient direction. Recall that the gradient is the direction of *increase* and therefore the negative gradient is the direction of *decrease* and we're trying to *minimize* a cost function.
#
# The amount by which we move in the negative gradient *direction*  is called the 'step size'. We stop when we are 'sufficiently close' to the optimum. Unlike in Week 2, this time we will set a **maximum number of iterations** and take gradient steps until we reach this maximum number. If no maximum number is supplied, the maximum should be set 100 by default. (Use default parameter values in Python.)
#
# With this in mind, complete the following gradient descent function below using your derivative function above. For each step in the gradient descent, we update the weight for each feature before computing our stopping criteria.

# %%
from math import sqrt
def ridge_regression_gradient_descent(feature_matrix, output, \
            initial_weights, step_size, l2_penalty, max_iterations=100):
    weights = np.array(initial_weights) # make sure it's a numpy array
    iterNum = 0
    #while not reached maximum number of iterations:
    while iterNum < max_iterations:
        iterNum += 1
        print "iteration %d: weights: %s" % (iterNum, weights)        
        # compute the predictions based on feature_matrix and weights using your predict_output() function
        predictions = predict_output(feature_matrix, weights)

        # compute the errors as predictions - output
        errors = predictions - output

        gradient_sum_squares = 0 # initialize the gradient sum of squares
        for i in xrange(len(weights)): # loop over each weight
            # Recall that feature_matrix[:,i] is the feature column associated with weights[i]
            # compute the derivative for weight[i].
            #(Remember: when i=0, you are computing the derivative of the constant!)
            derivative = feature_derivative_ridge(errors, \
                    feature_matrix[:, i], weights[i], l2_penalty, i == 0)
            
            # add the squared value of the derivative to the gradient magnitude 
            #   (for assessing convergence)
            gradient_sum_squares += derivative ** 2            

            # subtract the step size times the derivative from the current weight
            weights[i] = weights[i] - step_size * derivative
            
        # compute the square-root of the gradient sum of squares to get the 
        #   gradient magnitude:
        gradient_magnitude = sqrt(gradient_sum_squares)
        print "   gradient_magnitude: %f" % (gradient_magnitude)
#         if gradient_magnitude < tolerance:
#             converged = True
            
    return weights

# %% [markdown]
# # Visualizing effect of L2 penalty

# %% [markdown]
# The L2 penalty gets its name because it causes weights to have small L2 norms than otherwise. Let's see how large weights get penalized. Let us consider a simple model with 1 feature:

# %%
simple_features = ['sqft_living']
my_output = 'price'

# %% [markdown]
# Let us split the dataset into training set and test set. Make sure to use `seed=0`:

# %%
glbObsFit, glbObsOOB = \
    glbObsTrn.random_split(.7324,seed=glbObsTrnPartitionSeed)
print 'glbObsFit.shape:%d x %d' % (glbObsFit.shape[0], glbObsFit.shape[1])
print 'glbObsOOB.shape:%d x %d' % (glbObsOOB.shape[0], glbObsOOB.shape[1])
# Out:
# glbObsFit.shape:12692 x 22
# glbObsOOB.shape:4692 x 22

# %% [markdown]
# In this part, we will only use `'sqft_living'` to predict `'price'`. Use the `get_numpy_data` function to get a Numpy versions of your data with only this feature, for both the `train_data` and the `test_data`.

# %%
(simple_train_feature_matrix, train_output) = \
    get_numpy_data(glbObsTrn, simple_features, my_output)
(simple_test_feature_matrix , test_output ) = \
    get_numpy_data(glbObsNew, simple_features, my_output)

# %% [markdown]
# Let's set the parameters for our optimization:

# %%
initial_weights = np.array([0., 0.])
step_size = 1e-12
max_iterations=1000

# %% [markdown]
# First, let's consider no regularization.  Set the `l2_penalty` to `0.0` and run your ridge regression algorithm to learn the weights of your model.  Call your weights:
#
# `simple_weights_0_penalty`
#
# we'll use them later.

# %%
# def ridge_regression_gradient_descent(feature_matrix, output, \
#             initial_weights, step_size, l2_penalty, max_iterations=100)
simple_weights_0_penalty = ridge_regression_gradient_descent(\
                            simple_train_feature_matrix, train_output, \
                        initial_weights, step_size, 0.0, max_iterations)
print simple_weights_0_penalty
# Out:
# iteration 1: weights: [ 0.  0.]
#    gradient_magnitude: 47332517421285.750000
# iteration 2: weights: [  1.87526989e-02   4.73325137e+01]
#    gradient_magnitude: 38814797358381.546875
# iteration 3: weights: [  3.40823824e-02   8.61473080e+01]
#    gradient_magnitude: 31829883049923.511719
# iteration 4: weights: [  4.66050390e-02   1.17977189e+02]
#    gradient_magnitude: 26101938537076.929688
# iteration 5: weights: [  5.68258070e-02   1.44079125e+02]
#    gradient_magnitude: 21404765902862.546875
# iteration 6: weights: [  6.51589226e-02   1.65483889e+02]
#    gradient_magnitude: 17552872661595.664062
# iteration 7: weights: [  7.19440782e-02   1.83036761e+02]
#    gradient_magnitude: 14394146615672.886719
# iteration 8: weights: [  7.74598369e-02   1.97430906e+02]
#    gradient_magnitude: 11803848908023.369141
# iteration 9: weights: [  8.19346328e-02   2.09234754e+02]
#    gradient_magnitude: 9679688054413.705078
# iteration 10: weights: [  8.55557924e-02   2.18914442e+02]
#    gradient_magnitude: 7937780427944.611328
# iteration 11: weights: [  8.84769317e-02   2.26852222e+02]
#    gradient_magnitude: 6509337674295.583008
# iteration 12: weights: [  9.08240229e-02   2.33361559e+02]
#    gradient_magnitude: 5337950242942.037109
# iteration 13: weights: [  9.27003687e-02   2.38699509e+02]
#    gradient_magnitude: 4377359760334.144531
# iteration 14: weights: [  9.41906821e-02   2.43076868e+02]
#    gradient_magnitude: 3589632275514.707031
# iteration 15: weights: [  9.53644315e-02   2.46666500e+02]
#    gradient_magnitude: 2943660239202.458008
# iteration 16: weights: [  9.62785842e-02   2.49610161e+02]
#    gradient_magnitude: 2413934059132.200195
# iteration 17: weights: [  9.69798558e-02   2.52024094e+02]
#    gradient_magnitude: 1979534720073.818604
# iteration 18: weights: [  9.75065555e-02   2.54003629e+02]
#    gradient_magnitude: 1623307686851.248291
# iteration 19: weights: [  9.78900982e-02   2.55626937e+02]
#    gradient_magnitude: 1331185467590.956299
# iteration 20: weights: [  9.81562458e-02   2.56958122e+02]
#    gradient_magnitude: 1091632085058.542969
# iteration 21: weights: [  9.83261241e-02   2.58049754e+02]
#    gradient_magnitude: 895187518122.046875
# iteration 22: weights: [  9.84170572e-02   2.58944942e+02]
#    gradient_magnitude: 734094123224.817505
# iteration 23: weights: [  9.84432517e-02   2.59679036e+02]
#    gradient_magnitude: 601990283161.404785
# iteration 24: weights: [  9.84163577e-02   2.60281026e+02]
#    gradient_magnitude: 493659185272.333008
# iteration 25: weights: [  9.83459286e-02   2.60774685e+02]
#    gradient_magnitude: 404822808247.946228
# iteration 26: weights: [  9.82397989e-02   2.61179508e+02]
#    gradient_magnitude: 331972982030.040222
# iteration 27: weights: [  9.81043930e-02   2.61511481e+02]
#    gradient_magnitude: 272232849326.124359
# iteration 28: weights: [  9.79449794e-02   2.61783714e+02]
#    gradient_magnitude: 223243257817.696808
# iteration 29: weights: [  9.77658783e-02   2.62006957e+02]
#    gradient_magnitude: 183069596663.460327
# iteration 30: weights: [  9.75706326e-02   2.62190027e+02]
#    gradient_magnitude: 150125398248.338531
# iteration 31: weights: [  9.73621476e-02   2.62340152e+02]
#    gradient_magnitude: 123109688192.852585
# iteration 32: weights: [  9.71428058e-02   2.62463261e+02]
#    gradient_magnitude: 100955609559.609863
# iteration 33: weights: [  9.69145609e-02   2.62564217e+02]
#    gradient_magnitude: 82788292414.264938
# iteration 34: weights: [  9.66790150e-02   2.62647005e+02]
#    gradient_magnitude: 67890304999.716812
# iteration 35: weights: [  9.64374821e-02   2.62714895e+02]
#    gradient_magnitude: 55673322182.133141
# iteration 36: weights: [  9.61910395e-02   2.62770567e+02]
#    gradient_magnitude: 45654892348.717392
# iteration 37: weights: [  9.59405707e-02   2.62816222e+02]
#    gradient_magnitude: 37439385276.375717
# iteration 38: weights: [  9.56868003e-02   2.62853660e+02]
#    gradient_magnitude: 30702368597.979343
# iteration 39: weights: [  9.54303225e-02   2.62884361e+02]
#    gradient_magnitude: 25177795888.892570
# iteration 40: weights: [  9.51716243e-02   2.62909538e+02]
#    gradient_magnitude: 20647500427.981850
# iteration 41: weights: [  9.49111055e-02   2.62930184e+02]
#    gradient_magnitude: 16932579738.759626
# iteration 42: weights: [  9.46490935e-02   2.62947114e+02]
#    gradient_magnitude: 13886330683.283535
# iteration 43: weights: [  9.43858572e-02   2.62960998e+02]
#    gradient_magnitude: 11388456112.523096
# iteration 44: weights: [  9.41216169e-02   2.62972383e+02]
#    gradient_magnitude: 9340314289.854542
# iteration 45: weights: [  9.38565531e-02   2.62981720e+02]
#    gradient_magnitude: 7661023481.508882
# iteration 46: weights: [  9.35908142e-02   2.62989376e+02]
#    gradient_magnitude: 6284267874.840869
# iteration 47: weights: [  9.33245216e-02   2.62995655e+02]
#    gradient_magnitude: 5155678673.977427
# iteration 48: weights: [  9.30577749e-02   2.63000804e+02]
#    gradient_magnitude: 268815261.058005
# iteration 385: weights: [  2.47638120e-03   2.63024302e+02]
#    gradient_magnitude: 268815259.524311
# iteration 386: weights: [  2.20756596e-03   2.63024303e+02]
#    gradient_magnitude: 268815257.990618
# iteration 387: weights: [  1.93875072e-03   2.63024303e+02]
#    gradient_magnitude: 268815256.456923
# iteration 388: weights: [  1.66993549e-03   2.63024303e+02]
#    gradient_magnitude: 268815254.923229
# iteration 389: weights: [  1.40112025e-03   2.63024303e+02]
#    gradient_magnitude: 268815253.389536
# iteration 390: weights: [  1.13230502e-03   2.63024303e+02]
#    gradient_magnitude: 268815251.855842
# iteration 391: weights: [  8.63489792e-04   2.63024303e+02]
#    gradient_magnitude: 268815250.322148
# iteration 392: weights: [  5.94674564e-04   2.63024303e+02]
#    gradient_magnitude: 268815248.788455
# iteration 393: weights: [  3.25859337e-04   2.63024303e+02]
#    gradient_magnitude: 268815247.254761
# iteration 394: weights: [  5.70441111e-05   2.63024303e+02]
#    gradient_magnitude: 268815245.721068
# iteration 395: weights: [ -2.11771113e-04   2.63024304e+02]
#    gradient_magnitude: 268815244.187374
# iteration 396: weights: [ -4.80586335e-04   2.63024304e+02]
#    gradient_magnitude: 268815242.653681
# iteration 397: weights: [ -7.49401556e-04   2.63024304e+02]
#    gradient_magnitude: 268815241.119987
# iteration 398: weights: [ -1.01821678e-03   2.63024304e+02]
#    gradient_magnitude: 268815239.586294
# iteration 399: weights: [ -1.28703199e-03   2.63024304e+02]
#    gradient_magnitude: 268815238.052599
# iteration 400: weights: [ -1.55584721e-03   2.63024304e+02]
#    gradient_magnitude: 268815236.518905
# iteration 401: weights: [ -1.82466242e-03   2.63024304e+02]
#    gradient_magnitude: 268815234.985212
# iteration 402: weights: [ -2.09347764e-03   2.63024304e+02]
#    gradient_magnitude: 268815233.451519
# iteration 403: weights: [ -2.36229285e-03   2.63024304e+02]
#    gradient_magnitude: 268815231.917826
# iteration 404: weights: [ -2.63110806e-03   2.63024304e+02]
#    gradient_magnitude: 268815230.384132
# iteration 405: weights: [ -2.89992327e-03   2.63024305e+02]
#    gradient_magnitude: 268815228.850439
# iteration 406: weights: [ -3.16873848e-03   2.63024305e+02]
#    gradient_magnitude: 268815227.316745
# iteration 407: weights: [ -3.43755368e-03   2.63024305e+02]
#    gradient_magnitude: 268815225.783051
# iteration 408: weights: [ -3.70636889e-03   2.63024305e+02]
#    gradient_magnitude: 268815224.249357
# iteration 409: weights: [ -3.97518409e-03   2.63024305e+02]
#    gradient_magnitude: 268815222.715665
# iteration 410: weights: [ -4.24399929e-03   2.63024305e+02]
#    gradient_magnitude: 268815221.181970
# iteration 411: weights: [ -4.51281449e-03   2.63024305e+02]
#    gradient_magnitude: 268815219.648277
# iteration 412: weights: [ -4.78162969e-03   2.63024305e+02]
#    gradient_magnitude: 268815218.114583
# iteration 413: weights: [ -5.05044488e-03   2.63024305e+02]
#    gradient_magnitude: 268815216.580891
# iteration 414: weights: [ -5.31926008e-03   2.63024306e+02]
#    gradient_magnitude: 268815215.047201
# iteration 415: weights: [ -5.58807527e-03   2.63024306e+02]
#    gradient_magnitude: 268815213.513503
# iteration 416: weights: [ -5.85689046e-03   2.63024306e+02]
#    gradient_magnitude: 268815211.979809
# iteration 417: weights: [ -6.12570565e-03   2.63024306e+02]
#    gradient_magnitude: 268815210.446116
# iteration 418: weights: [ -6.39452084e-03   2.63024306e+02]
#    gradient_magnitude: 268815208.912423
# iteration 419: weights: [ -6.66333603e-03   2.63024306e+02]
#    gradient_magnitude: 268815207.378730
# iteration 420: weights: [ -6.93215121e-03   2.63024306e+02]
#    gradient_magnitude: 268815205.845037
# iteration 421: weights: [ -7.20096640e-03   2.63024306e+02]
#    gradient_magnitude: 268815204.311343
# iteration 422: weights: [ -7.46978158e-03   2.63024306e+02]
#    gradient_magnitude: 268815202.777650
# iteration 423: weights: [ -7.73859676e-03   2.63024307e+02]
#    gradient_magnitude: 268815201.243956
# iteration 424: weights: [ -8.00741194e-03   2.63024307e+02]
#    gradient_magnitude: 268815199.710262
# iteration 425: weights: [ -8.27622712e-03   2.63024307e+02]
#    gradient_magnitude: 268815198.176569
# iteration 426: weights: [ -8.54504230e-03   2.63024307e+02]
#    gradient_magnitude: 268815196.642876
# iteration 427: weights: [ -8.81385747e-03   2.63024307e+02]
#    gradient_magnitude: 268815195.109183
# iteration 428: weights: [ -9.08267264e-03   2.63024307e+02]
#    gradient_magnitude: 268815193.575489
# iteration 429: weights: [ -9.35148782e-03   2.63024307e+02]
#    gradient_magnitude: 268815192.041796
# iteration 430: weights: [ -9.62030299e-03   2.63024307e+02]
#    gradient_magnitude: 268815190.508102
# iteration 431: weights: [ -9.88911816e-03   2.63024307e+02]
#    gradient_magnitude: 268815188.974410
# iteration 432: weights: [ -1.01579333e-02   2.63024307e+02]
#    gradient_magnitude: 268815187.440715
# iteration 433: weights: [ -1.04267485e-02   2.63024308e+02]
#    gradient_magnitude: 268815185.907023
# iteration 434: weights: [ -1.06955637e-02   2.63024308e+02]
#    gradient_magnitude: 268815184.373329
# iteration 435: weights: [ -1.09643788e-02   2.63024308e+02]
#    gradient_magnitude: 268815182.839636
# iteration 436: weights: [ -1.12331940e-02   2.63024308e+02]
#    gradient_magnitude: 268815181.305943
# iteration 437: weights: [ -1.15020091e-02   2.63024308e+02]
#    gradient_magnitude: 268815179.772249
# iteration 438: weights: [ -1.17708243e-02   2.63024308e+02]
#    gradient_magnitude: 268815178.238557
# iteration 439: weights: [ -1.20396395e-02   2.63024308e+02]
#    gradient_magnitude: 268815176.704863
# iteration 440: weights: [ -1.23084546e-02   2.63024308e+02]
#    gradient_magnitude: 268815175.171170
# iteration 441: weights: [ -1.25772698e-02   2.63024308e+02]
#    gradient_magnitude: 268815173.637477
# iteration 442: weights: [ -1.28460849e-02   2.63024309e+02]
#    gradient_magnitude: 268815172.103784
# iteration 443: weights: [ -1.31149001e-02   2.63024309e+02]
#    gradient_magnitude: 268815170.570091
# iteration 444: weights: [ -1.33837152e-02   2.63024309e+02]
#    gradient_magnitude: 268815123.025604
# iteration 475: weights: [ -2.17169841e-02   2.63024312e+02]
#    gradient_magnitude: 268815121.491912
# iteration 476: weights: [ -2.19857992e-02   2.63024312e+02]
#    gradient_magnitude: 268815119.958219
# iteration 477: weights: [ -2.22546143e-02   2.63024312e+02]
#    gradient_magnitude: 268815118.424526
# iteration 478: weights: [ -2.25234294e-02   2.63024312e+02]
#    gradient_magnitude: 268815116.890833
# iteration 479: weights: [ -2.27922445e-02   2.63024313e+02]
#    gradient_magnitude: 268815115.357140
# iteration 480: weights: [ -2.30610595e-02   2.63024313e+02]
# ...
#    gradient_magnitude: 268814560.160887
# iteration 842: weights: [ -1.20372023e-01   2.63024352e+02]
#    gradient_magnitude: 268814558.627197
# iteration 843: weights: [ -1.20640837e-01   2.63024352e+02]
#    gradient_magnitude: 268814557.093507
# iteration 844: weights: [ -1.20909652e-01   2.63024352e+02]
#    gradient_magnitude: 268814555.559817
# iteration 845: weights: [ -1.21178466e-01   2.63024352e+02]
#    gradient_magnitude: 268814554.026128
# iteration 846: weights: [ -1.21447281e-01   2.63024352e+02]
#    gradient_magnitude: 268814552.492438
# iteration 847: weights: [ -1.21716095e-01   2.63024352e+02]
#    gradient_magnitude: 268814550.958749
# iteration 848: weights: [ -1.21984910e-01   2.63024352e+02]
#    gradient_magnitude: 268814549.425059
# iteration 849: weights: [ -1.22253724e-01   2.63024353e+02]
#    gradient_magnitude: 268814547.891369
# iteration 850: weights: [ -1.22522539e-01   2.63024353e+02]
#    gradient_magnitude: 268814546.357680
# iteration 851: weights: [ -1.22791353e-01   2.63024353e+02]
#    gradient_magnitude: 268814544.823990
# iteration 852: weights: [ -1.23060168e-01   2.63024353e+02]
#    gradient_magnitude: 268814543.290300
# iteration 853: weights: [ -1.23328983e-01   2.63024353e+02]
#    gradient_magnitude: 268814541.756612
# iteration 854: weights: [ -1.23597797e-01   2.63024353e+02]
#    gradient_magnitude: 268814540.222921
# iteration 855: weights: [ -1.23866612e-01   2.63024353e+02]
#    gradient_magnitude: 268814538.689232
# iteration 856: weights: [ -1.24135426e-01   2.63024353e+02]
#    gradient_magnitude: 268814537.155542
# iteration 857: weights: [ -1.24404241e-01   2.63024353e+02]
#    gradient_magnitude: 268814535.621852
# iteration 858: weights: [ -1.24673055e-01   2.63024354e+02]
#    gradient_magnitude: 268814534.088163
# iteration 859: weights: [ -1.24941870e-01   2.63024354e+02]
#    gradient_magnitude: 268814532.554473
# iteration 860: weights: [ -1.25210684e-01   2.63024354e+02]
#    gradient_magnitude: 268814531.020784
# iteration 861: weights: [ -1.25479499e-01   2.63024354e+02]
#    gradient_magnitude: 268814529.487093
# iteration 862: weights: [ -1.25748313e-01   2.63024354e+02]
#    gradient_magnitude: 268814527.953404
# iteration 863: weights: [ -1.26017128e-01   2.63024354e+02]
#    gradient_magnitude: 268814526.419714
# iteration 864: weights: [ -1.26285942e-01   2.63024354e+02]
#    gradient_magnitude: 268814524.886026
# iteration 865: weights: [ -1.26554757e-01   2.63024354e+02]
#    gradient_magnitude: 268814523.352337
# iteration 866: weights: [ -1.26823571e-01   2.63024354e+02]
#    gradient_magnitude: 268814521.818646
# iteration 867: weights: [ -1.27092386e-01   2.63024354e+02]
#    gradient_magnitude: 268814520.284957
# iteration 868: weights: [ -1.27361200e-01   2.63024355e+02]
#    gradient_magnitude: 268814518.751267
# iteration 869: weights: [ -1.27630015e-01   2.63024355e+02]
#    gradient_magnitude: 268814517.217578
# iteration 870: weights: [ -1.27898829e-01   2.63024355e+02]
#    gradient_magnitude: 268814515.683888
# iteration 871: weights: [ -1.28167644e-01   2.63024355e+02]
#    gradient_magnitude: 268814514.150199
# iteration 872: weights: [ -1.28436458e-01   2.63024355e+02]
#    gradient_magnitude: 268814512.616509
# iteration 873: weights: [ -1.28705273e-01   2.63024355e+02]
#    gradient_magnitude: 268814511.082820
# iteration 874: weights: [ -1.28974087e-01   2.63024355e+02]
#    gradient_magnitude: 268814509.549130
# iteration 875: weights: [ -1.29242902e-01   2.63024355e+02]
#    gradient_magnitude: 268814508.015441
# iteration 876: weights: [ -1.29511716e-01   2.63024355e+02]
#    gradient_magnitude: 268814506.481752
# iteration 877: weights: [ -1.29780531e-01   2.63024356e+02]
#    gradient_magnitude: 268814504.948062
# iteration 878: weights: [ -1.30049345e-01   2.63024356e+02]
#    gradient_magnitude: 268814503.414370
# iteration 879: weights: [ -1.30318160e-01   2.63024356e+02]
#    gradient_magnitude: 268814501.880683
# iteration 880: weights: [ -1.30586974e-01   2.63024356e+02]
#    gradient_magnitude: 268814500.346994
# iteration 881: weights: [ -1.30855788e-01   2.63024356e+02]
#    gradient_magnitude: 268814498.813305
# iteration 882: weights: [ -1.31124603e-01   2.63024356e+02]
#    gradient_magnitude: 268814497.279615
# iteration 883: weights: [ -1.31393417e-01   2.63024356e+02]
#    gradient_magnitude: 268814495.745926
# iteration 884: weights: [ -1.31662232e-01   2.63024356e+02]
#    gradient_magnitude: 268814494.212236
# iteration 885: weights: [ -1.31931046e-01   2.63024356e+02]
#    gradient_magnitude: 268814492.678547
# iteration 886: weights: [ -1.32199861e-01   2.63024357e+02]
#    gradient_magnitude: 268814491.144858
# iteration 887: weights: [ -1.32468675e-01   2.63024357e+02]
#    gradient_magnitude: 268814489.611168
# iteration 888: weights: [ -1.32737490e-01   2.63024357e+02]
#    gradient_magnitude: 268814488.077480
# iteration 889: weights: [ -1.33006304e-01   2.63024357e+02]
#    gradient_magnitude: 268814486.543790
# iteration 890: weights: [ -1.33275119e-01   2.63024357e+02]
#    gradient_magnitude: 268814485.010101
# iteration 891: weights: [ -1.33543933e-01   2.63024357e+02]
#    gradient_magnitude: 268814483.476412
# iteration 892: weights: [ -1.33812748e-01   2.63024357e+02]
#    gradient_magnitude: 268814481.942722
# iteration 893: weights: [ -1.34081562e-01   2.63024357e+02]
#    gradient_magnitude: 268814480.409033
# iteration 894: weights: [ -1.34350377e-01   2.63024357e+02]
#    gradient_magnitude: 268814478.875344
# iteration 895: weights: [ -1.34619191e-01   2.63024358e+02]
#    gradient_magnitude: 268814477.341655
# iteration 896: weights: [ -1.34888005e-01   2.63024358e+02]
#    gradient_magnitude: 268814475.807965
# iteration 897: weights: [ -1.35156820e-01   2.63024358e+02]
#    gradient_magnitude: 268814474.274276
# iteration 898: weights: [ -1.35425634e-01   2.63024358e+02]
#    gradient_magnitude: 268814472.740586
# iteration 899: weights: [ -1.35694449e-01   2.63024358e+02]
#    gradient_magnitude: 268814471.206896
# iteration 900: weights: [ -1.35963263e-01   2.63024358e+02]
#    gradient_magnitude: 268814469.673208
# iteration 901: weights: [ -1.36232078e-01   2.63024358e+02]
#    gradient_magnitude: 268814468.139519
# iteration 902: weights: [ -1.36500892e-01   2.63024358e+02]
#    gradient_magnitude: 268814466.605830
# iteration 903: weights: [ -1.36769707e-01   2.63024358e+02]
#    gradient_magnitude: 268814465.072141
# iteration 904: weights: [ -1.37038521e-01   2.63024358e+02]
#    gradient_magnitude: 268814463.538452
# iteration 905: weights: [ -1.37307336e-01   2.63024359e+02]
#    gradient_magnitude: 268814462.004761
# iteration 906: weights: [ -1.37576150e-01   2.63024359e+02]
#    gradient_magnitude: 268814460.471073
# iteration 907: weights: [ -1.37844964e-01   2.63024359e+02]
#    gradient_magnitude: 268814458.937384
# iteration 908: weights: [ -1.38113779e-01   2.63024359e+02]
#    gradient_magnitude: 268814457.403695
# iteration 909: weights: [ -1.38382593e-01   2.63024359e+02]
#    gradient_magnitude: 268814455.870006
# iteration 910: weights: [ -1.38651408e-01   2.63024359e+02]
#    gradient_magnitude: 268814454.336317
# iteration 911: weights: [ -1.38920222e-01   2.63024359e+02]
#    gradient_magnitude: 268814452.802628
# iteration 912: weights: [ -1.39189037e-01   2.63024359e+02]
#    gradient_magnitude: 268814451.268938
# iteration 913: weights: [ -1.39457851e-01   2.63024359e+02]
#    gradient_magnitude: 268814449.735250
# iteration 914: weights: [ -1.39726665e-01   2.63024360e+02]
#    gradient_magnitude: 268814448.201560
# iteration 915: weights: [ -1.39995480e-01   2.63024360e+02]
#    gradient_magnitude: 268814446.667871
# iteration 916: weights: [ -1.40264294e-01   2.63024360e+02]
#    gradient_magnitude: 268814445.134182
# iteration 917: weights: [ -1.40533109e-01   2.63024360e+02]
#    gradient_magnitude: 268814443.600493
# iteration 918: weights: [ -1.40801923e-01   2.63024360e+02]
#    gradient_magnitude: 268814442.066804
# iteration 919: weights: [ -1.41070738e-01   2.63024360e+02]
#    gradient_magnitude: 268814440.533115
# iteration 920: weights: [ -1.41339552e-01   2.63024360e+02]
#    gradient_magnitude: 268814438.999426
# iteration 921: weights: [ -1.41608366e-01   2.63024360e+02]
#    gradient_magnitude: 268814437.465737
# iteration 922: weights: [ -1.41877181e-01   2.63024360e+02]
#    gradient_magnitude: 268814435.932048
# iteration 923: weights: [ -1.42145995e-01   2.63024361e+02]
#    gradient_magnitude: 268814434.398359
# iteration 924: weights: [ -1.42414810e-01   2.63024361e+02]
#    gradient_magnitude: 268814432.864670
# iteration 925: weights: [ -1.42683624e-01   2.63024361e+02]
#    gradient_magnitude: 268814431.330981
# iteration 926: weights: [ -1.42952438e-01   2.63024361e+02]
#    gradient_magnitude: 268814429.797292
# iteration 927: weights: [ -1.43221253e-01   2.63024361e+02]
#    gradient_magnitude: 268814428.263603
# iteration 928: weights: [ -1.43490067e-01   2.63024361e+02]
#    gradient_magnitude: 268814426.729914
# iteration 929: weights: [ -1.43758882e-01   2.63024361e+02]
#    gradient_magnitude: 268814425.196224
# iteration 930: weights: [ -1.44027696e-01   2.63024361e+02]
#    gradient_magnitude: 268814423.662536
# iteration 931: weights: [ -1.44296510e-01   2.63024361e+02]
#    gradient_magnitude: 268814422.128847
# iteration 932: weights: [ -1.44565325e-01   2.63024362e+02]
#    gradient_magnitude: 268814420.595159
# iteration 933: weights: [ -1.44834139e-01   2.63024362e+02]
#    gradient_magnitude: 268814419.061469
# iteration 934: weights: [ -1.45102954e-01   2.63024362e+02]
#    gradient_magnitude: 268814417.527781
# iteration 935: weights: [ -1.45371768e-01   2.63024362e+02]
#    gradient_magnitude: 268814415.994092
# iteration 936: weights: [ -1.45640582e-01   2.63024362e+02]
#    gradient_magnitude: 268814414.460403
# iteration 937: weights: [ -1.45909397e-01   2.63024362e+02]
#    gradient_magnitude: 268814412.926713
# iteration 938: weights: [ -1.46178211e-01   2.63024362e+02]
#    gradient_magnitude: 268814411.393025
# iteration 939: weights: [ -1.46447026e-01   2.63024362e+02]
#    gradient_magnitude: 268814409.859336
# iteration 940: weights: [ -1.46715840e-01   2.63024362e+02]
#    gradient_magnitude: 268814408.325647
# iteration 941: weights: [ -1.46984654e-01   2.63024362e+02]
#    gradient_magnitude: 268814406.791958
# iteration 942: weights: [ -1.47253469e-01   2.63024363e+02]
#    gradient_magnitude: 268814405.258269
# iteration 943: weights: [ -1.47522283e-01   2.63024363e+02]
#    gradient_magnitude: 268814403.724581
# iteration 944: weights: [ -1.47791098e-01   2.63024363e+02]
#    gradient_magnitude: 268814402.190892
# iteration 945: weights: [ -1.48059912e-01   2.63024363e+02]
#    gradient_magnitude: 268814400.657202
# iteration 946: weights: [ -1.48328726e-01   2.63024363e+02]
#    gradient_magnitude: 268814399.123514
# iteration 947: weights: [ -1.48597541e-01   2.63024363e+02]
#    gradient_magnitude: 268814397.589825
# iteration 948: weights: [ -1.48866355e-01   2.63024363e+02]
#    gradient_magnitude: 268814396.056136
# iteration 949: weights: [ -1.49135169e-01   2.63024363e+02]
#    gradient_magnitude: 268814394.522447
# iteration 950: weights: [ -1.49403984e-01   2.63024363e+02]
#    gradient_magnitude: 268814392.988759
# iteration 951: weights: [ -1.49672798e-01   2.63024364e+02]
#    gradient_magnitude: 268814391.455070
# iteration 952: weights: [ -1.49941613e-01   2.63024364e+02]
#    gradient_magnitude: 268814389.921381
# iteration 953: weights: [ -1.50210427e-01   2.63024364e+02]
#    gradient_magnitude: 268814388.387701
# iteration 954: weights: [ -1.50479241e-01   2.63024364e+02]
#    gradient_magnitude: 268814386.854005
# iteration 955: weights: [ -1.50748056e-01   2.63024364e+02]
#    gradient_magnitude: 268814385.320315
# iteration 956: weights: [ -1.51016870e-01   2.63024364e+02]
#    gradient_magnitude: 268814383.786626
# iteration 957: weights: [ -1.51285684e-01   2.63024364e+02]
#    gradient_magnitude: 268814382.252938
# iteration 958: weights: [ -1.51554499e-01   2.63024364e+02]
#    gradient_magnitude: 268814380.719249
# iteration 959: weights: [ -1.51823313e-01   2.63024364e+02]
#    gradient_magnitude: 268814379.185560
# iteration 960: weights: [ -1.52092127e-01   2.63024365e+02]
#    gradient_magnitude: 268814377.651871
# iteration 961: weights: [ -1.52360942e-01   2.63024365e+02]
#    gradient_magnitude: 268814376.118183
# iteration 962: weights: [ -1.52629756e-01   2.63024365e+02]
#    gradient_magnitude: 268814374.584494
# iteration 963: weights: [ -1.52898571e-01   2.63024365e+02]
#    gradient_magnitude: 268814373.050805
# iteration 964: weights: [ -1.53167385e-01   2.63024365e+02]
#    gradient_magnitude: 268814371.517117
# iteration 965: weights: [ -1.53436199e-01   2.63024365e+02]
#    gradient_magnitude: 268814369.983428
# iteration 966: weights: [ -1.53705014e-01   2.63024365e+02]
#    gradient_magnitude: 268814368.449739
# iteration 967: weights: [ -1.53973828e-01   2.63024365e+02]
#    gradient_magnitude: 268814366.916051
# iteration 968: weights: [ -1.54242642e-01   2.63024365e+02]
#    gradient_magnitude: 268814365.382362
# iteration 969: weights: [ -1.54511457e-01   2.63024366e+02]
#    gradient_magnitude: 268814363.848673
# iteration 970: weights: [ -1.54780271e-01   2.63024366e+02]
#    gradient_magnitude: 268814362.314985
# iteration 971: weights: [ -1.55049085e-01   2.63024366e+02]
#    gradient_magnitude: 268814360.781297
# iteration 972: weights: [ -1.55317900e-01   2.63024366e+02]
#    gradient_magnitude: 268814359.247608
# iteration 973: weights: [ -1.55586714e-01   2.63024366e+02]
#    gradient_magnitude: 268814357.713920
# iteration 974: weights: [ -1.55855528e-01   2.63024366e+02]
#    gradient_magnitude: 268814356.180231
# iteration 975: weights: [ -1.56124343e-01   2.63024366e+02]
#    gradient_magnitude: 268814354.646542
# iteration 976: weights: [ -1.56393157e-01   2.63024366e+02]
#    gradient_magnitude: 268814353.112853
# iteration 977: weights: [ -1.56661971e-01   2.63024366e+02]
#    gradient_magnitude: 268814351.579165
# iteration 978: weights: [ -1.56930786e-01   2.63024366e+02]
#    gradient_magnitude: 268814350.045477
# iteration 979: weights: [ -1.57199600e-01   2.63024367e+02]
#    gradient_magnitude: 268814348.511788
# iteration 980: weights: [ -1.57468414e-01   2.63024367e+02]
#    gradient_magnitude: 268814346.978099
# iteration 981: weights: [ -1.57737229e-01   2.63024367e+02]
#    gradient_magnitude: 268814345.444411
# iteration 982: weights: [ -1.58006043e-01   2.63024367e+02]
#    gradient_magnitude: 268814343.910723
# iteration 983: weights: [ -1.58274857e-01   2.63024367e+02]
#    gradient_magnitude: 268814342.377034
# iteration 984: weights: [ -1.58543672e-01   2.63024367e+02]
#    gradient_magnitude: 268814340.843346
# iteration 985: weights: [ -1.58812486e-01   2.63024367e+02]
#    gradient_magnitude: 268814339.309657
# iteration 986: weights: [ -1.59081300e-01   2.63024367e+02]
#    gradient_magnitude: 268814337.775969
# iteration 987: weights: [ -1.59350115e-01   2.63024367e+02]
#    gradient_magnitude: 268814336.242280
# iteration 988: weights: [ -1.59618929e-01   2.63024368e+02]
#    gradient_magnitude: 268814334.708591
# iteration 989: weights: [ -1.59887743e-01   2.63024368e+02]
#    gradient_magnitude: 268814333.174904
# iteration 990: weights: [ -1.60156557e-01   2.63024368e+02]
#    gradient_magnitude: 268814331.641216
# iteration 991: weights: [ -1.60425372e-01   2.63024368e+02]
#    gradient_magnitude: 268814330.107527
# iteration 992: weights: [ -1.60694186e-01   2.63024368e+02]
#    gradient_magnitude: 268814328.573839
# iteration 993: weights: [ -1.60963000e-01   2.63024368e+02]
#    gradient_magnitude: 268814327.040150
# iteration 994: weights: [ -1.61231815e-01   2.63024368e+02]
#    gradient_magnitude: 268814325.506462
# iteration 995: weights: [ -1.61500629e-01   2.63024368e+02]
#    gradient_magnitude: 268814323.972774
# iteration 996: weights: [ -1.61769443e-01   2.63024368e+02]
#    gradient_magnitude: 268814322.439084
# iteration 997: weights: [ -1.62038258e-01   2.63024369e+02]
#    gradient_magnitude: 268814320.905396
# iteration 998: weights: [ -1.62307072e-01   2.63024369e+02]
#    gradient_magnitude: 268814319.371708
# iteration 999: weights: [ -1.62575886e-01   2.63024369e+02]
#    gradient_magnitude: 268814317.838019
# iteration 1000: weights: [ -1.62844700e-01   2.63024369e+02]
#    gradient_magnitude: 268814316.304331
# [ -1.63113515e-01   2.63024369e+02]

# %% [markdown]
# Next, let's consider high regularization.  Set the `l2_penalty` to `1e11` and run your ridge regression algorithm to learn the weights of your model.  Call your weights:
#
# `simple_weights_high_penalty`
#
# we'll use them later.

# %%
simple_weights_high_penalty = ridge_regression_gradient_descent(\
                            simple_train_feature_matrix, train_output, \
                        initial_weights, step_size, 1e11, max_iterations)
print simple_weights_high_penalty

# %% [markdown]
# This code will plot the two learned models.  (The blue line is for the model with no regularization and the red line is for the one with high regularization.)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(simple_train_feature_matrix, train_output, 'k.',
         simple_train_feature_matrix, \
             predict_output(simple_train_feature_matrix, \
                            simple_weights_0_penalty), 'b-',
         simple_train_feature_matrix, \
             predict_output(simple_train_feature_matrix, \
                            simple_weights_high_penalty), 'r-')

# %% [markdown]
# Compute the RSS on the TEST data for the following three sets of weights:
# 1. The initial weights (all zeros)
# 2. The weights learned with no regularization
# 3. The weights learned with high regularization
#
# Which weights perform best?

# %%
# Refactor to feature_matrix an input (done below)
def get_test_RSS(weights):
    return ((test_output - \
        predict_output(simple_test_feature_matrix, weights)) ** 2).sum()

# %%
print 'Test RSS: Weights: All 0:%s' % (get_test_RSS(initial_weights))
print 'Test RSS: Weights: l2_penalty 0:%s' % \
                            (get_test_RSS(simple_weights_0_penalty))
print 'Test RSS: Weights: l2_penalty High:%s' % \
                            (get_test_RSS(simple_weights_high_penalty))

# %% [markdown]
# ***QUIZ QUESTIONS***
# 1. What is the value of the coefficient for `sqft_living` that you learned with no regularization, rounded to 1 decimal place?  What about the one with high regularization?
# 2. Comparing the lines you fit with the with no regularization versus high regularization, which one is steeper?
# 3. What are the RSS on the test data for each of the set of weights above (initial, no regularization, high regularization)?

# %% [markdown]
# # Running a multiple regression with L2 penalty

# %% [markdown]
# Let us now consider a model with 2 features: `['sqft_living', 'sqft_living15']`.

# %% [markdown]
# First, create Numpy versions of your training and test data with these two features.

# %%
model_features = ['sqft_living', 'sqft_living15'] # sqft_living15 is the average squarefeet for the nearest 15 neighbors. 
my_output = 'price'
(feature_matrix, output) = get_numpy_data(train_data, model_features, my_output)
(test_feature_matrix, test_output) = get_numpy_data(test_data, model_features, my_output)

# %% [markdown]
# We need to re-inialize the weights, since we have one extra parameter. Let us also set the step size and maximum number of iterations.

# %%
initial_weights = np.array([0.0,0.0,0.0])
step_size = 1e-12
max_iterations = 1000

# %% [markdown]
# First, let's consider no regularization.  Set the `l2_penalty` to `0.0` and run your ridge regression algorithm to learn the weights of your model.  Call your weights:
#
# `multiple_weights_0_penalty`

# %%
multiple_weights_0_penalty = ridge_regression_gradient_descent(\
                            feature_matrix, output, \
                        initial_weights, step_size, 0.0, max_iterations)
print multiple_weights_0_penalty

# %% [markdown]
# Next, let's consider high regularization.  Set the `l2_penalty` to `1e11` and run your ridge regression algorithm to learn the weights of your model.  Call your weights:
#
# `multiple_weights_high_penalty`

# %%
multiple_weights_high_penalty = ridge_regression_gradient_descent(\
                            feature_matrix, output, \
                        initial_weights, step_size, 1e11, max_iterations)
print multiple_weights_high_penalty

# %% [markdown]
# Compute the RSS on the TEST data for the following three sets of weights:
# 1. The initial weights (all zeros)
# 2. The weights learned with no regularization
# 3. The weights learned with high regularization
#
# Which weights perform best?

# %%
def get_test_RSS(feature_matrix, weights):
    return ((test_output - \
             predict_output(feature_matrix, weights)) ** 2).sum()

# %%
print 'Test Multiple RSS: Weights:           All 0:%.4e' % \
    (get_test_RSS(test_feature_matrix, initial_weights))
print 'Test Multiple RSS: Weights: l2_penalty    0:%.4e' % \
    (get_test_RSS(test_feature_matrix, multiple_weights_0_penalty))
print 'Test Multiple RSS: Weights: l2_penalty High:%.4e' % \
    (get_test_RSS(test_feature_matrix, multiple_weights_high_penalty))

# %% [markdown]
# Predict the house price for the 1st house in the test set using the no regularization and high regularization models. (Remember that python starts indexing from 0.) How far is the prediction from the actual price?  Which weights perform best for the 1st house?

# %%
print glbObsNew[0, glb_rsp_var]

# %%
print predict_output(feature_matrix[0,:], multiple_weights_0_penalty   )
print predict_output(feature_matrix[0,:], multiple_weights_high_penalty)

# %% [markdown]
# ***QUIZ QUESTIONS***
# 1. What is the value of the coefficient for `sqft_living` that you learned with no regularization, rounded to 1 decimal place?  What about the one with high regularization?
# 2. What are the RSS on the test data for each of the set of weights above (initial, no regularization, high regularization)?
# 3. We make prediction for the first house in the test set using two sets of weights (no regularization vs high regularization). Which weights make better prediction <u>for that particular house</u>?
